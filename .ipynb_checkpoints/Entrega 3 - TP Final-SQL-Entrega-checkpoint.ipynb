# %% [markdown]
# # TP1 Data acquisition - EDA

# %%
import numpy as np
import pyodbc 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
from matplotlib.ticker import PercentFormatter

import pypyodbc

# %%
SERVER_NAME='SPARK-BA-00003\SQLEXPRESS'
DATABASE_NAME='olist'
ready = True
try:
    conn=pypyodbc.connect("""
    Driver={{SQL Server Native Client 11.0}};
    Server={0};
    Database={1};
    Trusted_Connection=yes;""".format(SERVER_NAME, DATABASE_NAME))
except pypyodbc.ex as ex:
            ready = (except_msg)

if ready==True:
    print('Conexion exitosa a SQL Server')
else:
    print(ready)
# Out:
# Conexion exitosa a SQL Server

# %%
#Carga datasets desde la base de datos
#Se implementa error handling
try:
    #Carga Ordenes
    dfOrders=pd.read_sql("SELECT * from olist_orders", conn)
    #Carga Lineas de pedido de cada orden
    dfOrderItems = pd.read_sql("SELECT * from olist_order_items", conn)
    #Carga Productos
    dfProductos = pd.read_sql("SELECT * from olist_products", conn)
    #Carga Vendedores
    dfOrderSellers = pd.read_sql("SELECT * from olist_sellers", conn)
    #Carga Pagos de ordenes
    dfOrderPayments = pd.read_sql("SELECT * from olist_order_payments", conn)
    #Carga Clientes
    dfCustomers=pd.read_sql("SELECT * from olist_customers", conn)
    #Carga Reviews de clientes a cada orden
    dfOrderReviews = pd.read_sql("SELECT * from olist_order_reviews", conn)
    #Carga Categoria Productos
    dfPrdCat=pd.read_sql("SELECT * from product_category_name_translation", conn)
    print('Todos los dataframes han sido cargados desde SQL Server - Base', DATABASE_NAME)
except pypyodbc.ex as e:
    print(except_msg)
# Out:
# Todos los dataframes han sido cargados desde SQL Server - Base olist

# %% [markdown]
# ### Se depreca la carga por archivos CSV de entregas TP1 y TP2.
# strqueryOrders = r'C:\Users\usuario\Desktop\CoderData\Data\olist_orders_dataset.csv'
# strqueryOrderItems = r'C:\Users\usuario\Desktop\CoderData\Data\olist_order_items_dataset.csv'
# strqueryProductos = r'C:\Users\usuario\Desktop\CoderData\Data\olist_products_dataset.csv'
# strquerySellers = r'C:\Users\usuario\Desktop\CoderData\Data\olist_sellers_dataset.csv'
# strqueryPayments = r'C:\Users\usuario\Desktop\CoderData\Data\olist_order_payments_dataset.csv'
# strqueryCustomers = r'C:\Users\usuario\Desktop\CoderData\Data\olist_customers_dataset.csv'
# strqueryReviews = r'C:\Users\usuario\Desktop\CoderData\Data\olist_order_reviews_dataset.csv'
# strqueryCatProd = r'C:\Users\usuario\Desktop\CoderData\Data\product_category_name_translation.csv'
#
# dfOrders = pd.read_csv(strqueryOrders, sep = ",")
# dfOrderItems = pd.read_csv(strqueryOrderItems, sep = ",")
# dfProductos = pd.read_csv(strqueryProductos, sep = ",")
# dfOrderSellers = pd.read_csv(strquerySellers, sep = ",")
# dfOrderPayments = pd.read_csv(strqueryPayments, sep = ",")
# dfCustomers=pd.read_csv(strqueryCustomers, sep = ",")
# dfOrderReviews = pd.read_csv(strqueryReviews, sep = ",")
# dfPrdCat=pd.read_csv(strqueryCatProd, sep = ",")

# %% [markdown]
# ## EDA

# %%
dfOrders.head().round()
# Out:
#                            order_id                       customer_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1  00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2  000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3  00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-09-13 08:59:02 2017-09-13 09:45:35
# 1    delivered      2017-04-26 10:53:06 2017-04-26 11:05:13
# 2    delivered      2018-01-14 14:33:31 2018-01-14 14:48:30
# 3    delivered      2018-08-08 10:00:35 2018-08-08 10:10:18
# 4    delivered      2017-02-04 13:57:51 2017-02-04 14:10:13
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-09-19 18:34:16           2017-09-20 23:43:48
# 1          2017-05-04 14:35:00           2017-05-12 16:04:24
# 2          2018-01-16 12:36:48           2018-01-22 13:19:16
# 3          2018-08-10 13:28:00           2018-08-14 13:32:39
# 4          2017-02-16 09:46:09           2017-03-01 16:42:31
#
#   order_estimated_delivery_date
# 0                    2017-09-29
# 1                    2017-05-15
# 2                    2018-02-05
# 3                    2018-08-20
# 4                    2017-03-17

# %%
dfOrderItems.head().round()
# Out:
#                            order_id order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214             1
# 1  00018f77f2f0320c557190d7a144bdd3             1
# 2  000229ec398224ef6ca0657da4fc703e             1
# 3  00024acbcdf0a6daa1e931b038114c75             1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9             1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date    price  freight_value
# 0 2017-09-19 09:45:35   5890.0         1329.0
# 1 2017-05-03 11:05:13  23990.0         1993.0
# 2 2018-01-18 14:48:30  19900.0         1787.0
# 3 2018-08-15 10:10:18   1299.0         1279.0
# 4 2017-02-13 13:57:51  19990.0         1814.0

# %%
dfPrdCat.head().round()
# Out:
#     product_category_name product_category_name_english
# 0              parfumaria                     perfumery
# 1            beleza_saude                 health_beauty
# 2  informatica_acessorios         computers_accessories
# 3              automotivo                          auto
# 4         cama_mesa_banho                bed_bath_table

# %%
dfOrderSellers.head().round()
# Out:
#                           seller_id  seller_zip_code_prefix  seller_city  \
# 0  0015a82c2db000af6aaaf3ae2ecb0532                    9080  santo andre
# 1  001cca7ae9ae17fb1caed9dfb1094831                   29156    cariacica
# 2  001e6ad469a905060d959994f1b41e4f                   24754  sao goncalo
# 3  002100f778ceb8431b7a1020ff7ab48f                   14405       franca
# 4  003554e2dce176b5555353e4f3555ac8                   74565      goiania
#
#   seller_state
# 0           SP
# 1           ES
# 2           RJ
# 3           SP
# 4           GO

# %%
dfOrderPayments.head().round()
# Out:
#                            order_id payment_sequential payment_type  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                  1  credit_card
# 1  00018f77f2f0320c557190d7a144bdd3                  1  credit_card
# 2  000229ec398224ef6ca0657da4fc703e                  1  credit_card
# 3  00024acbcdf0a6daa1e931b038114c75                  1  credit_card
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                  1  credit_card
#
#   payment_installments  payment_value
# 0                    2         7219.0
# 1                    3        25983.0
# 2                    5        21687.0
# 3                    2         2578.0
# 4                    3        21804.0

# %%
dfCustomers.head().round()
# Out:
#                         customer_id                customer_unique_id  \
# 0  00012a2ce6f8dcda20d059ce98491703  248ffe10d632bebe4f7267f1f44844c9
# 1  000161a058600d5901f007fab4c27140  b0015e09bb4b6e47c52844fab5fb6638
# 2  0001fd6190edaaf884bcaf3d49edf079  94b11d37cd61cb2994a194d11f89682b
# 3  0002414f95344307404f0ace7a26f1d5  4893ad4ea28b2c5b3ddf4e82e79db9e6
# 4  000379cdec625522490c315e70c7a9fb  0b83f73b19c2019e182fd552c048a22c
#
#    customer_zip_code_prefix customer_city customer_state
# 0                      6273        osasco             SP
# 1                     35550   itapecerica             MG
# 2                     29830  nova venecia             ES
# 3                     39664      mendonca             MG
# 4                      4841     sao paulo             SP

# %%
dfOrderReviews.head().round()
# Out:
#                           review_id                          order_id  \
# 0  0001239bc1de2e33cb583967c2ca4c67  fc046d7776171871436844218f817d7d
# 1  0001cc6860aeaf5b9017fe4131a52e62  d4665434b01caa9dc3e3e78b3eb3593e
# 2  00020c7512a52e92212f12d3e37513c0  e28abf2eb2f1fbcbdc2dd0cd9a561671
# 3  00032b0141443497c898b3093690af51  04fb47576993a3cb0c12d4b25eab6e4e
# 4  00034d88989f9a4c393bdcaec301537f  5f358d797a49fe2f24352f73426215f6
#
#   review_score review_comment_title  \
# 0            5                 None
# 1            5                 None
# 2            5      Entrega rápida!
# 3            5                 None
# 4            5                 None
#
#                               review_comment_message review_creation_date  \
# 0                                               None           2018-03-20
# 1                                               None           2018-06-22
# 2  A entrega foi super rápida e o pendente é lind...           2018-04-25
# 3                                               None           2017-05-30
# 4                                               None           2017-08-12
#
#   review_answer_timestamp
# 0     2018-03-20 18:36:04
# 1     2018-06-26 13:51:29
# 2     2018-04-26 14:55:36
# 3     2017-06-01 23:28:55
# 4     2017-08-13 19:56:53

# %%
dfPrdCat.head().round()
# Out:
#     product_category_name product_category_name_english
# 0              parfumaria                     perfumery
# 1            beleza_saude                 health_beauty
# 2  informatica_acessorios         computers_accessories
# 3              automotivo                          auto
# 4         cama_mesa_banho                bed_bath_table

# %%
#Dimension del dataset
print('Shape Ordenes: ', dfOrders.shape)
print('Shape Items por orden: ', dfOrderItems.shape)
print('Shape Productos: ', dfProductos.shape)
print('Shape Sellers: ', dfOrderSellers.shape)
print('Shape Pagos: ', dfOrderPayments.shape)
print('Shape Customers: ', dfCustomers.shape)
print('Shape Reviews: ', dfOrderReviews.shape)
print('Shape Categoria Productos: ', dfPrdCat.shape)
# Out:
# Shape Ordenes:  (99441, 8)
# Shape Items por orden:  (112650, 7)
# Shape Productos:  (32951, 9)
# Shape Sellers:  (3095, 4)
# Shape Pagos:  (103886, 5)
# Shape Customers:  (99441, 5)
# Shape Reviews:  (100000, 7)
# Shape Categoria Productos:  (72, 2)

# %%
#Nombre de los atributos
dfOrders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
dfOrderItems.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
dfProductos.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
dfOrderSellers.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
dfOrderPayments.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
dfCustomers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
dfOrderReviews.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
dfPrdCat.columns
# Out:
# Index(['product_category_name', 'product_category_name_english'], dtype='object')

# %%
#Tipo de dato para cada columna
dfOrders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
dfOrderItems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  object
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Existen columnas sin datos. La conclusión temprana es que son aquellos pedidos que están pendientes de aprobacion y/o entrega

# %%
dfProductos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  object
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 2.3+ MB

# %%
dfOrderSellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
dfOrderPayments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  object
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  object
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 4.0+ MB

# %%
dfCustomers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
dfOrderReviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  object
#  3   review_comment_title     11713 non-null   object
#  4   review_comment_message   41746 non-null   object
#  5   review_creation_date     100000 non-null  datetime64[ns]
#  6   review_answer_timestamp  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 5.3+ MB

# %%
dfPrdCat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          72 non-null     object
#  1   product_category_name_english  72 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
#Desactivo warnings para facilitar lectura
import warnings
warnings.filterwarnings("ignore")

# %%
#Primeras estadisticas
dfOrders.describe().round()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     40c85c3c87215ae5945521e74ef0cfca  9438adb7579bb0133f0173f39f85ae01
# freq                                   1                                 1
# first                                NaN                               NaN
# last                                 NaN                               NaN
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2017-11-20 11:46:30  2018-02-27 04:31:10
# freq          96478                        3                    9
# first           NaN      2016-09-04 21:15:19  2016-09-15 12:16:38
# last            NaN      2018-10-17 17:30:18  2018-09-03 17:40:06
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-07-24 21:36:42
# freq                             47                             3
# first           2016-10-08 10:34:01           2016-10-11 13:46:32
# last            2018-09-11 19:48:28           2018-10-17 13:22:46
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522
# first            2016-09-30 00:00:00
# last             2018-11-12 00:00:00

# %%
dfOrderItems.describe().round()
# Out:
#           price  freight_value
# count  112650.0       112650.0
# mean    12065.0         1999.0
# std     18363.0         1581.0
# min        85.0            0.0
# 25%      3990.0         1308.0
# 50%      7499.0         1626.0
# 75%     13490.0         2115.0
# max    673500.0        40968.0

# %%
dfPrdCat.describe().round()
# Out:
#         product_category_name product_category_name_english
# count                      72                            72
# unique                     72                            71
# top     utilidades_domesticas                     perfumery
# freq                        1                             2

# %%
dfOrderSellers.describe().round()
# Out:
#        seller_zip_code_prefix
# count                  3095.0
# mean                  32291.0
# std                   32713.0
# min                    1001.0
# 25%                    7094.0
# 50%                   14940.0
# 75%                   64552.0
# max                   99730.0

# %%
dfOrderPayments.describe().round()
# Out:
#        payment_value
# count       103886.0
# mean         15410.0
# std          21749.0
# min              0.0
# 25%           5679.0
# 50%          10000.0
# 75%          17184.0
# max        1366408.0

# %%
dfCustomers.describe().round()
# Out:
#        customer_zip_code_prefix
# count                   99441.0
# mean                    35137.0
# std                     29798.0
# min                      1003.0
# 25%                     11347.0
# 50%                     24416.0
# 75%                     58900.0
# max                     99990.0

# %%
dfOrderReviews.describe().round()
# Out:
#                                review_id                          order_id  \
# count                             100000                            100000
# unique                             99173                             99441
# top     0c76e7a547a531e7bf9f0b99cba071c1  03c939fd7fd3b38f8485a0f95798f1f6
# freq                                   3                                 3
# first                                NaN                               NaN
# last                                 NaN                               NaN
#
#        review_score review_comment_title review_comment_message  \
# count        100000                11713                  41746
# unique            5                 4583                  36919
# top               5            Recomendo              Muito bom
# freq          57420                  426                    230
# first           NaN                  NaN                    NaN
# last            NaN                  NaN                    NaN
#
#        review_creation_date review_answer_timestamp
# count                100000                  100000
# unique                  637                   99010
# top     2017-12-19 00:00:00     2017-06-15 23:21:05
# freq                    466                       4
# first   2016-10-02 00:00:00     2016-10-07 18:32:28
# last    2018-08-31 00:00:00     2018-10-29 12:27:35

# %%
dfPrdCat.describe().round()
# Out:
#         product_category_name product_category_name_english
# count                      72                            72
# unique                     72                            71
# top     utilidades_domesticas                     perfumery
# freq                        1                             2

# %% [markdown]
# Una vez analizados los datasets individuales, es necesario combinarlos para realizar un análisis mas detallado

# %%
#Merge de Ordenes con sus lineas de pedidos
dfOrdenesCompletas=pd.merge(dfOrders, dfOrderItems, left_on='order_id', right_on='order_id')
#Merge de Ordenes con sus clientes
dfOrdenesCompletas=dfOrdenesCompletas.merge(dfCustomers, on='customer_id')
#Merge de Ordenes con productos
dfOrdenesCompletas=dfOrdenesCompletas.merge(dfProductos, on='product_id')
#Merge de Ordenes con pagos
dfOrdenesCompletas=dfOrdenesCompletas.merge(dfOrderPayments, on='order_id')
#Merge de Ordenes con Vendedores
dfOrdenesCompletas=dfOrdenesCompletas.merge(dfOrderSellers, on='seller_id')
#Merge de Ordenes con categoría de productos
dfOrdenesCompletas=dfOrdenesCompletas.merge(dfPrdCat, on='product_category_name')
#Merge de Ordenes con review de clientes
dfOrdenesCompletas=dfOrdenesCompletas.merge(dfOrderReviews, on='order_id')

# %%
dfOrdenesCompletas.head(25)
# Out:
#                             order_id                       customer_id  \
# 0   00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1   130898c0987d1801452a8ed92a670612  e6eecc5a77de221464d1c4eaff0a9b64
# 2   532ed5e14e24ae1f0d735b91524b98b9  4ef55bf80f711b372afebcb7c715344a
# 3   6f8c31653edb8c83e1a739408b5ff750  30407a72ad8b3f4df4d15369126b20c9
# 4   7d19f4ef4d04461989632411b7e588b9  91a792fef70ecd8cc69d3c7feb3d12da
# 5   a0f9acf0b6294ed8561e32cde1a966bc  4851b3bca4a48b395dfad7aa57c3f72a
# 6   bbf796534aaf9c59f8da8c7982db56e0  c32c207d9ebf75958011557ac1624e2f
# 7   c9ef97d2854afe64a3b4488bc2836af6  0a29abf475fb8039d2775913d6f0b6f0
# 8   c9ef97d2854afe64a3b4488bc2836af6  0a29abf475fb8039d2775913d6f0b6f0
# 9   df2d910b8b5e5f461f67043489f9569d  2e76c1f2a920153d79cc98b634c50942
# 10  df2d910b8b5e5f461f67043489f9569d  2e76c1f2a920153d79cc98b634c50942
# 11  df2d910b8b5e5f461f67043489f9569d  2e76c1f2a920153d79cc98b634c50942
# 12  0191bbb5166d4b9a68df11797d5acfa9  62b59a64eb786a96516229b7f3612c72
# 13  8a4df9820e049472302bf6362daecb8b  87f51a0f934f82e81d8680ef1afeaf48
# 14  9bd5ab93fc163dd17a9d531c39806e05  35fd6066756cc7d4d5e5d456fecc8422
# 15  bf3b217e5505e5e9d746120dbb93b562  0669f5398348b7260f7f14411736e78f
# 16  c0e6a4b9d9b4fb7364f6010863708cbd  a12b256adc8a574b2ef0bec1edaea319
# 17  d24633e7c227ea7a234d568eefb493a9  0831a589bfb84d7db1725b029edd19af
# 18  0188777fe321843a18be24a6e9aa1e53  dc573d2a61a467e5e2826c1729691859
# 19  d829ae9ca5e0a9749f2574b62eb7ac10  a64e11fc5ee980cd9a2f1ac08110bc44
# 20  d829ae9ca5e0a9749f2574b62eb7ac10  a64e11fc5ee980cd9a2f1ac08110bc44
# 21  03054d8a8eefc2981cfad06f58e27979  9bd2f246e81c19f65c539ce426288ef5
# 22  26ab105de6689a556ce3ab6932ee68e6  08ad76732d8c6428ac2fb9eea89ff342
# 23  7766424657aa0cfbf1703f9550144964  35b6b3b06cd4b2101cfabfb5429dc028
# 24  a72c3152ab2259acdae64303a9a12efc  0a05250f6702d7949e237fa591546429
#
#    order_status order_purchase_timestamp   order_approved_at  \
# 0     delivered      2017-09-13 08:59:02 2017-09-13 09:45:35
# 1     delivered      2017-06-28 11:52:20 2017-06-29 02:44:11
# 2     delivered      2018-05-18 10:25:53 2018-05-18 12:31:43
# 3     delivered      2017-08-01 18:38:42 2017-08-01 18:55:08
# 4     delivered      2017-08-10 21:48:40 2017-08-10 22:05:11
# 5     delivered      2017-07-27 15:11:51 2017-07-28 15:23:46
# 6     delivered      2018-03-18 21:00:44 2018-03-20 03:28:44
# 7     delivered      2017-08-05 16:59:05 2017-08-08 04:25:34
# 8     delivered      2017-08-05 16:59:05 2017-08-08 04:25:34
# 9     delivered      2017-06-05 12:22:19 2017-06-05 14:31:21
# 10    delivered      2017-06-05 12:22:19 2017-06-05 14:31:21
# 11    delivered      2017-06-05 12:22:19 2017-06-05 14:31:21
# 12    delivered      2017-08-10 12:17:35 2017-08-10 12:30:15
# 13    delivered      2017-08-07 12:28:44 2017-08-07 13:03:05
# 14    delivered      2017-09-27 21:06:52 2017-09-27 21:14:23
# 15      shipped      2017-08-24 07:15:30 2017-08-24 07:25:13
# 16    delivered      2017-09-28 18:30:29 2017-09-28 18:49:20
# 17    delivered      2017-09-23 23:59:42 2017-09-24 00:24:40
# 18    delivered      2017-07-23 16:13:37 2017-07-25 14:35:11
# 19    delivered      2017-07-12 12:04:28 2017-07-13 02:56:03
# 20    delivered      2017-07-12 12:04:28 2017-07-13 02:56:03
# 21    delivered      2017-10-02 10:25:22 2017-10-03 10:35:11
# 22    delivered      2017-07-19 20:42:33 2017-07-19 20:55:09
# 23    delivered      2017-08-08 11:24:19 2017-08-08 11:43:36
# 24    delivered      2017-09-05 20:42:50 2017-09-05 20:55:20
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 0           2017-09-19 18:34:16           2017-09-20 23:43:48
# 1           2017-07-05 12:00:33           2017-07-13 20:39:29
# 2           2018-05-23 14:05:00           2018-06-04 18:34:26
# 3           2017-08-02 19:07:36           2017-08-09 21:26:33
# 4           2017-08-11 19:43:07           2017-08-24 20:04:21
# 5           2017-08-02 18:32:34           2017-08-31 20:19:52
# 6           2018-03-20 18:08:45           2018-03-28 21:57:44
# 7           2017-08-10 16:40:11           2017-08-14 18:13:03
# 8           2017-08-10 16:40:11           2017-08-14 18:13:03
# 9           2017-06-07 13:09:07           2017-06-26 13:52:03
# 10          2017-06-07 13:09:07           2017-06-26 13:52:03
# 11          2017-06-07 13:09:07           2017-06-26 13:52:03
# 12          2017-08-15 19:26:45           2017-08-24 18:15:16
# 13          2017-08-10 16:42:51           2017-08-11 20:16:50
# 14          2017-10-04 15:22:41           2017-10-16 22:49:03
# 15          2017-08-28 18:32:49                           NaT
# 16          2017-10-04 14:04:26           2017-10-21 12:45:25
# 17          2017-09-27 19:27:31           2017-10-04 22:14:47
# 18          2017-07-27 18:45:50           2017-07-28 16:18:00
# 19          2017-07-14 16:23:42           2017-08-07 17:27:41
# 20          2017-07-14 16:23:42           2017-08-07 17:27:41
# 21          2017-10-09 17:57:50           2017-10-19 21:03:49
# 22          2017-07-21 17:15:57           2017-07-24 20:42:49
# 23          2017-08-10 16:42:52           2017-08-11 20:21:56
# 24          2017-09-18 18:41:53           2017-09-30 13:08:17
#
#    order_estimated_delivery_date order_item_id  \
# 0                     2017-09-29             1
# 1                     2017-07-26             1
# 2                     2018-06-07             1
# 3                     2017-08-25             1
# 4                     2017-09-01             1
# 5                     2017-08-24             1
# 6                     2018-04-12             1
# 7                     2017-09-06             2
# 8                     2017-09-06             1
# 9                     2017-07-06             1
# 10                    2017-07-06             1
# 11                    2017-07-06             1
# 12                    2017-09-08             1
# 13                    2017-08-22             1
# 14                    2017-10-23             1
# 15                    2017-09-18             1
# 16                    2017-11-01             1
# 17                    2017-10-19             1
# 18                    2017-08-08             1
# 19                    2017-08-09             1
# 20                    2017-08-09             2
# 21                    2017-10-25             1
# 22                    2017-08-03             1
# 23                    2017-08-23             1
# 24                    2017-10-02             1
#
#                           product_id  ... seller_zip_code_prefix  \
# 0   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 1   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 2   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 3   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 4   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 5   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 6   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 7   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 8   436c8d57ff8d4aa254318e9bd9b48c83  ...                  27277
# 9   4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 10  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 11  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 12  ec02a5d380128f7a188e9ce8f3ddd832  ...                  27277
# 13  ec02a5d380128f7a188e9ce8f3ddd832  ...                  27277
# 14  ec02a5d380128f7a188e9ce8f3ddd832  ...                  27277
# 15  ec02a5d380128f7a188e9ce8f3ddd832  ...                  27277
# 16  ec02a5d380128f7a188e9ce8f3ddd832  ...                  27277
# 17  ec02a5d380128f7a188e9ce8f3ddd832  ...                  27277
# 18  436c8d57ff8d4aa254318e9bd9b48c83  ...                  27277
# 19  436c8d57ff8d4aa254318e9bd9b48c83  ...                  27277
# 20  7f1a77bec0639e473392e91a504272a5  ...                  27277
# 21  3e31fd1419cc4cd6adad1925e72e3a03  ...                  27277
# 22  3e31fd1419cc4cd6adad1925e72e3a03  ...                  27277
# 23  3e31fd1419cc4cd6adad1925e72e3a03  ...                  27277
# 24  3e31fd1419cc4cd6adad1925e72e3a03  ...                  27277
#
#       seller_city  seller_state  product_category_name_english  \
# 0   volta redonda            SP                     cool_stuff
# 1   volta redonda            SP                     cool_stuff
# 2   volta redonda            SP                     cool_stuff
# 3   volta redonda            SP                     cool_stuff
# 4   volta redonda            SP                     cool_stuff
# 5   volta redonda            SP                     cool_stuff
# 6   volta redonda            SP                     cool_stuff
# 7   volta redonda            SP                     cool_stuff
# 8   volta redonda            SP                     cool_stuff
# 9   volta redonda            SP                     cool_stuff
# 10  volta redonda            SP                     cool_stuff
# 11  volta redonda            SP                     cool_stuff
# 12  volta redonda            SP                     cool_stuff
# 13  volta redonda            SP                     cool_stuff
# 14  volta redonda            SP                     cool_stuff
# 15  volta redonda            SP                     cool_stuff
# 16  volta redonda            SP                     cool_stuff
# 17  volta redonda            SP                     cool_stuff
# 18  volta redonda            SP                     cool_stuff
# 19  volta redonda            SP                     cool_stuff
# 20  volta redonda            SP                     cool_stuff
# 21  volta redonda            SP                     cool_stuff
# 22  volta redonda            SP                     cool_stuff
# 23  volta redonda            SP                     cool_stuff
# 24  volta redonda            SP                     cool_stuff
#
#                            review_id  review_score review_comment_title  \
# 0   97ca439bc427b48bc1cd7177abe71365             5                 None
# 1   b11cba360bbe71410c291b764753d37f             5                 None
# 2   af01c4017c5ab46df6cc810e069e654a             4      super recomendo
# 3   8304ff37d8b16b57086fa283fe0c44f8             5                 None
# 4   426f43a82185969503fb3c86241a9535             5                 None
# 5   c752337ac465a5e2fbdbedf7d79c6659             5                 None
# 6   b41646a4365a1411101396c097413907             5                 None
# 7   dbacd3ac90ace7ad49fe8b31bbad2808             5                 None
# 8   dbacd3ac90ace7ad49fe8b31bbad2808             5                 None
# 9   4e58c72bb0373240b2bd9bf84b493a69             1                 None
# 10  4e58c72bb0373240b2bd9bf84b493a69             1                 None
# 11  4e58c72bb0373240b2bd9bf84b493a69             1                 None
# 12  2eab04a8f45efa131d44cf58b37ab595             5                 None
# 13  e7c32a82a3e1bb6183f83994d84a09ee             5                 None
# 14  05beac6a836638af96fd768982ec3a03             5                 None
# 15  ad04c464738a477312422d0f3af40ddb             1                 None
# 16  b4f2d87d97feb72f3c6340e1e90d5175             5                 None
# 17  b773c1ffeeff133ea6402a2816607411             4                 None
# 18  1fac9acb29e014e3b9b393d5c8505f99             5                 None
# 19  fcbfc00f9d9b164703c45ac561257463             5                 None
# 20  fcbfc00f9d9b164703c45ac561257463             5                 None
# 21  9d0e152a1983460f059ddffcb8af03bb             5                 None
# 22  7fbca1c30eb039bbf627a2bfc16ca6a5             5                 None
# 23  606dfceb9d0b031ada009da29fd859e0             5                 None
# 24  462d99ff45db848c2ba1e25b04126522             5                 None
#
#                                review_comment_message review_creation_date  \
# 0      Perfeito, produto entregue antes do combinado.           2017-09-21
# 1   lannister como sempre, entregou certinho e den...           2017-07-14
# 2                               carrinho muito bonito           2018-06-05
# 3                                                None           2017-08-10
# 4                                                None           2017-08-25
# 5                                                None           2017-08-27
# 6   Muito bom chegou bem antes do prazo, produto d...           2018-03-29
# 7                                                None           2017-08-15
# 8                                                None           2017-08-15
# 9                        o carrinho veio com defeito.           2017-06-27
# 10                       o carrinho veio com defeito.           2017-06-27
# 11                       o carrinho veio com defeito.           2017-06-27
# 12  Recebi o patines em perfeitas condições bem an...           2017-08-25
# 13                                               None           2017-08-12
# 14                                               None           2017-10-17
# 15  Não posso dizer que gostei dessa loja ou que r...           2017-09-20
# 16                                               None           2017-10-22
# 17                                               None           2017-10-05
# 18                                              ÓTIMO           2017-07-29
# 19                                               None           2017-08-08
# 20                                               None           2017-08-08
# 21                                               None           2017-10-20
# 22                                               None           2017-07-25
# 23                                               None           2017-08-12
# 24                                               None           2017-10-01
#
#     review_answer_timestamp
# 0       2017-09-22 10:57:03
# 1       2017-07-17 12:50:07
# 2       2018-06-06 21:41:12
# 3       2017-08-13 03:35:17
# 4       2017-08-28 00:51:18
# 5       2017-08-27 12:30:09
# 6       2018-03-30 12:41:53
# 7       2017-08-24 19:35:04
# 8       2017-08-24 19:35:04
# 9       2017-06-30 14:26:54
# 10      2017-06-30 14:26:54
# 11      2017-06-30 14:26:54
# 12      2017-08-28 12:57:25
# 13      2017-08-15 15:04:13
# 14      2017-10-20 21:49:36
# 15      2017-09-22 15:40:19
# 16      2017-10-23 00:52:23
# 17      2017-10-22 13:35:02
# 18      2017-08-01 20:55:50
# 19      2017-08-09 00:00:56
# 20      2017-08-09 00:00:56
# 21      2017-10-20 23:45:27
# 22      2017-08-05 02:54:30
# 23      2017-08-14 13:05:07
# 24      2017-10-02 22:52:06
#
# [25 rows x 40 columns]

# %%
dfOrdenesCompletas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116581 entries, 0 to 116580
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       116581 non-null  object
#  1   customer_id                    116581 non-null  object
#  2   order_status                   116581 non-null  object
#  3   order_purchase_timestamp       116581 non-null  datetime64[ns]
#  4   order_approved_at              116567 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   115368 non-null  datetime64[ns]
#  6   order_delivered_customer_date  114066 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  116581 non-null  datetime64[ns]
#  8   order_item_id                  116581 non-null  object
#  9   product_id                     116581 non-null  object
#  10  seller_id                      116581 non-null  object
#  11  shipping_limit_date            116581 non-null  datetime64[ns]
#  12  price                          116581 non-null  float64
#  13  freight_value                  116581 non-null  float64
#  14  customer_unique_id             116581 non-null  object
#  15  customer_zip_code_prefix       116581 non-null  int64
#  16  customer_city                  116581 non-null  object
#  17  customer_state                 116581 non-null  object
#  18  product_category_name          116581 non-null  object
#  19  product_name_lenght            116581 non-null  float64
#  20  product_description_lenght     116581 non-null  float64
#  21  product_photos_qty             116581 non-null  object
#  22  product_weight_g               116580 non-null  float64
#  23  product_length_cm              116580 non-null  float64
#  24  product_height_cm              116580 non-null  float64
#  25  product_width_cm               116580 non-null  float64
#  26  payment_sequential             116581 non-null  object
#  27  payment_type                   116581 non-null  object
#  28  payment_installments           116581 non-null  object
#  29  payment_value                  116581 non-null  float64
#  30  seller_zip_code_prefix         116581 non-null  int64
#  31  seller_city                    116581 non-null  object
#  32  seller_state                   116581 non-null  object
#  33  product_category_name_english  116581 non-null  object
#  34  review_id                      116581 non-null  object
#  35  review_score                   116581 non-null  object
#  36  review_comment_title           13994 non-null   object
#  37  review_comment_message         49871 non-null   object
#  38  review_creation_date           116581 non-null  datetime64[ns]
#  39  review_answer_timestamp        116581 non-null  datetime64[ns]
# dtypes: datetime64[ns](8), float64(9), int64(2), object(21)
# memory usage: 36.5+ MB

# %%
dfOrdenesCompletas.describe().round()
# Out:
#           price  freight_value  customer_zip_code_prefix  product_name_lenght  \
# count  116581.0       116581.0                  116581.0             116581.0
# mean    12075.0         2006.0                   35053.0                 49.0
# std     18385.0         1585.0                   29818.0                 10.0
# min        85.0            0.0                    1003.0                  5.0
# 25%      3990.0         1308.0                   11310.0                 42.0
# 50%      7490.0         1632.0                   24315.0                 52.0
# 75%     13490.0         2122.0                   58600.0                 57.0
# max    673500.0        40968.0                   99980.0                 76.0
#
#        product_description_lenght  product_weight_g  product_length_cm  \
# count                    116581.0          116580.0           116580.0
# mean                        786.0            2116.0               30.0
# std                         653.0            3784.0               16.0
# min                           4.0               0.0                7.0
# 25%                         346.0             300.0               18.0
# 50%                         600.0             700.0               25.0
# 75%                         983.0            1800.0               38.0
# max                        3992.0           40425.0              105.0
#
#        product_height_cm  product_width_cm  payment_value  \
# count           116580.0          116580.0       116581.0
# mean                17.0              23.0        17291.0
# std                 13.0              12.0        26762.0
# min                  2.0               6.0            0.0
# 25%                  8.0              15.0         6100.0
# 50%                 13.0              20.0        10819.0
# 75%                 20.0              30.0        18972.0
# max                105.0             118.0      1366408.0
#
#        seller_zip_code_prefix
# count                116581.0
# mean                  24505.0
# std                   27625.0
# min                    1001.0
# 25%                    6429.0
# 50%                   13690.0
# 75%                   28495.0
# max                   99730.0

# %% [markdown]
# ## Análisis de datos nulos, faltantes

# %%
#Declaro array para recorrer el data set para obtener los indices NAN
#Listo los resultados
Campos_Nulos= [feature for feature in dfOrdenesCompletas.columns if dfOrdenesCompletas[feature].isnull().sum()>=1]
for feature in Campos_Nulos:
    print(feature, np.round(dfOrdenesCompletas[feature].isnull().mean()*100,4),'%', ' y el total de nulos es ', np.round(dfOrdenesCompletas[feature].isnull().sum(),4))
# Out:
# order_approved_at 0.012 %  y el total de nulos es  14
# order_delivered_carrier_date 1.0405 %  y el total de nulos es  1213
# order_delivered_customer_date 2.1573 %  y el total de nulos es  2515
# product_weight_g 0.0009 %  y el total de nulos es  1
# product_length_cm 0.0009 %  y el total de nulos es  1
# product_height_cm 0.0009 %  y el total de nulos es  1
# product_width_cm 0.0009 %  y el total de nulos es  1
# review_comment_title 87.9963 %  y el total de nulos es  102587
# review_comment_message 57.222 %  y el total de nulos es  66710

# %%
dfOrdenesCompletas.isnull().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1213
# order_delivered_customer_date      2515
# order_estimated_delivery_date         0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# product_category_name                 0
# product_name_lenght                   0
# product_description_lenght            0
# product_photos_qty                    0
# product_weight_g                      1
# product_length_cm                     1
# product_height_cm                     1
# product_width_cm                      1
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# seller_zip_code_prefix                0
# seller_city                           0
# seller_state                          0
# product_category_name_english         0
# review_id                             0
# review_score                          0
# review_comment_title             102587
# review_comment_message            66710
# review_creation_date                  0
# review_answer_timestamp               0
# dtype: int64

# %% [markdown]
# ## Data wrangling

# %%
#Limpieza de fechas nulas.

#Se guardan los indices donde las fechas de aprobacion son nulas 
index=(dfOrdenesCompletas[dfOrdenesCompletas['order_approved_at'].isnull()==True].index.values)

#Completamos la fecha de aprobación nula con la fecha de compra, asumiendo un proceso de aprobación automatica
dfOrdenesCompletas['order_approved_at'].fillna(dfOrdenesCompletas['order_purchase_timestamp'], inplace=True)

#La fecha de entrega al cliente nula, la completamos con la fecha estimada de entrega
index=(dfOrdenesCompletas[dfOrdenesCompletas['order_delivered_customer_date'].isnull()==True].index.values)
dfOrdenesCompletas['order_delivered_customer_date'].fillna(dfOrdenesCompletas['order_estimated_delivery_date'], inplace=True)

#La fecha de entrega carrier nula, la completamos con la fecha estimada de entrega
index=(dfOrdenesCompletas[dfOrdenesCompletas['order_delivered_carrier_date'].isnull()==True].index.values)
dfOrdenesCompletas['order_delivered_carrier_date'].fillna(dfOrdenesCompletas['order_estimated_delivery_date'], inplace=True)

# %%
#Chequeo resultados 
Campos_Nulos= [feature for feature in dfOrdenesCompletas.columns if dfOrdenesCompletas[feature].isnull().sum()>=1]
for feature in Campos_Nulos:
    print(feature, np.round(dfOrdenesCompletas[feature].isnull().mean()*100,4),'%', ' y el total de nulos es ', np.round(dfOrdenesCompletas[feature].isnull().sum(),4))
# Out:
# product_weight_g 0.0009 %  y el total de nulos es  1
# product_length_cm 0.0009 %  y el total de nulos es  1
# product_height_cm 0.0009 %  y el total de nulos es  1
# product_width_cm 0.0009 %  y el total de nulos es  1
# review_comment_title 87.9963 %  y el total de nulos es  102587
# review_comment_message 57.222 %  y el total de nulos es  66710

# %%
#Relleno el producto NAN con la media
for feature in Campos_Nulos:
    if 'product' in feature:
        dfOrdenesCompletas[feature].fillna(dfOrdenesCompletas[feature].median(), inplace=True)

# %%
#Relleno los NAN de Product Reviews con "Sin Titulo" y "Sin Comentarios"
dfOrdenesCompletas['review_comment_message'].fillna('Sin Revision', inplace=True)
dfOrdenesCompletas['review_comment_title'].fillna('Sin Titulo', inplace=True)

# %%
dfOrdenesCompletas.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# seller_zip_code_prefix           0
# seller_city                      0
# seller_state                     0
# product_category_name_english    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# review_answer_timestamp          0
# dtype: int64

# %%
dfOrdenesCompletas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116581 entries, 0 to 116580
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       116581 non-null  object
#  1   customer_id                    116581 non-null  object
#  2   order_status                   116581 non-null  object
#  3   order_purchase_timestamp       116581 non-null  datetime64[ns]
#  4   order_approved_at              116581 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   116581 non-null  datetime64[ns]
#  6   order_delivered_customer_date  116581 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  116581 non-null  datetime64[ns]
#  8   order_item_id                  116581 non-null  object
#  9   product_id                     116581 non-null  object
#  10  seller_id                      116581 non-null  object
#  11  shipping_limit_date            116581 non-null  datetime64[ns]
#  12  price                          116581 non-null  float64
#  13  freight_value                  116581 non-null  float64
#  14  customer_unique_id             116581 non-null  object
#  15  customer_zip_code_prefix       116581 non-null  int64
#  16  customer_city                  116581 non-null  object
#  17  customer_state                 116581 non-null  object
#  18  product_category_name          116581 non-null  object
#  19  product_name_lenght            116581 non-null  float64
#  20  product_description_lenght     116581 non-null  float64
#  21  product_photos_qty             116581 non-null  object
#  22  product_weight_g               116581 non-null  float64
#  23  product_length_cm              116581 non-null  float64
#  24  product_height_cm              116581 non-null  float64
#  25  product_width_cm               116581 non-null  float64
#  26  payment_sequential             116581 non-null  object
#  27  payment_type                   116581 non-null  object
#  28  payment_installments           116581 non-null  object
#  29  payment_value                  116581 non-null  float64
#  30  seller_zip_code_prefix         116581 non-null  int64
#  31  seller_city                    116581 non-null  object
#  32  seller_state                   116581 non-null  object
#  33  product_category_name_english  116581 non-null  object
#  34  review_id                      116581 non-null  object
#  35  review_score                   116581 non-null  object
#  36  review_comment_title           116581 non-null  object
#  37  review_comment_message         116581 non-null  object
#  38  review_creation_date           116581 non-null  datetime64[ns]
#  39  review_answer_timestamp        116581 non-null  datetime64[ns]
# dtypes: datetime64[ns](8), float64(9), int64(2), object(21)
# memory usage: 36.5+ MB

# %% [markdown]
# Para este ejercicio convertiremos los campos de fecha solo para diferenciar el dtype de los campos de textos que se usaran para clasificar, dado que no se utilizarán para la práctica final que no incluye análisis de series de tiempo

# %%
Fechas=['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date' , 'order_delivered_customer_date','order_estimated_delivery_date','review_creation_date','review_answer_timestamp','shipping_limit_date']
for columns in Fechas:
    dfOrdenesCompletas[columns]=dfOrdenesCompletas[columns].astype('datetime64[ns]')

# %%
dfOrdenesCompletas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116581 entries, 0 to 116580
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       116581 non-null  object
#  1   customer_id                    116581 non-null  object
#  2   order_status                   116581 non-null  object
#  3   order_purchase_timestamp       116581 non-null  datetime64[ns]
#  4   order_approved_at              116581 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   116581 non-null  datetime64[ns]
#  6   order_delivered_customer_date  116581 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  116581 non-null  datetime64[ns]
#  8   order_item_id                  116581 non-null  object
#  9   product_id                     116581 non-null  object
#  10  seller_id                      116581 non-null  object
#  11  shipping_limit_date            116581 non-null  datetime64[ns]
#  12  price                          116581 non-null  float64
#  13  freight_value                  116581 non-null  float64
#  14  customer_unique_id             116581 non-null  object
#  15  customer_zip_code_prefix       116581 non-null  int64
#  16  customer_city                  116581 non-null  object
#  17  customer_state                 116581 non-null  object
#  18  product_category_name          116581 non-null  object
#  19  product_name_lenght            116581 non-null  float64
#  20  product_description_lenght     116581 non-null  float64
#  21  product_photos_qty             116581 non-null  object
#  22  product_weight_g               116581 non-null  float64
#  23  product_length_cm              116581 non-null  float64
#  24  product_height_cm              116581 non-null  float64
#  25  product_width_cm               116581 non-null  float64
#  26  payment_sequential             116581 non-null  object
#  27  payment_type                   116581 non-null  object
#  28  payment_installments           116581 non-null  object
#  29  payment_value                  116581 non-null  float64
#  30  seller_zip_code_prefix         116581 non-null  int64
#  31  seller_city                    116581 non-null  object
#  32  seller_state                   116581 non-null  object
#  33  product_category_name_english  116581 non-null  object
#  34  review_id                      116581 non-null  object
#  35  review_score                   116581 non-null  object
#  36  review_comment_title           116581 non-null  object
#  37  review_comment_message         116581 non-null  object
#  38  review_creation_date           116581 non-null  datetime64[ns]
#  39  review_answer_timestamp        116581 non-null  datetime64[ns]
# dtypes: datetime64[ns](8), float64(9), int64(2), object(21)
# memory usage: 36.5+ MB

# %%
#Seleccion de segmentaciones
features_numericos=[feature for feature in dfOrdenesCompletas.columns if dfOrdenesCompletas[feature].dtype =='int64']

# %%
features_categoricos=[feature for feature in dfOrdenesCompletas.columns if dfOrdenesCompletas[feature].dtype=='object']

# %%
features_numericos
# Out:
# ['customer_zip_code_prefix', 'seller_zip_code_prefix']

# %%
features_categoricos
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'customer_unique_id',
#  'customer_city',
#  'customer_state',
#  'product_category_name',
#  'product_photos_qty',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'seller_city',
#  'seller_state',
#  'product_category_name_english',
#  'review_id',
#  'review_score',
#  'review_comment_title',
#  'review_comment_message']

# %% [markdown]
# ## Analisis Univariado

# %%
# Análisis univariado sobre clientes
dfClientes=dfOrdenesCompletas[['customer_id', 'payment_value', 'order_id', 'customer_city', 'customer_state', 'customer_unique_id', 'payment_type']]

# %%
dfClientes.head()
# Out:
#                         customer_id  payment_value  \
# 0  3ce436f183e68e07877b285a838db11a         7219.0
# 1  e6eecc5a77de221464d1c4eaff0a9b64         7386.0
# 2  4ef55bf80f711b372afebcb7c715344a         8323.0
# 3  30407a72ad8b3f4df4d15369126b20c9         7507.0
# 4  91a792fef70ecd8cc69d3c7feb3d12da         7219.0
#
#                            order_id          customer_city customer_state  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  campos dos goytacazes             RJ
# 1  130898c0987d1801452a8ed92a670612                  jatai             GO
# 2  532ed5e14e24ae1f0d735b91524b98b9         belo horizonte             MG
# 3  6f8c31653edb8c83e1a739408b5ff750   sao jose dos pinhais             PR
# 4  7d19f4ef4d04461989632411b7e588b9   conselheiro lafaiete             MG
#
#                  customer_unique_id payment_type
# 0  871766c5855e863f6eccc05f988b23cb  credit_card
# 1  0fb8e3eab2d3e79d92bb3fffbb97f188       boleto
# 2  3419052c8c6b45daf79c1e426f9e9bcb  credit_card
# 3  e7c828d22c0682c1565252deefbe334d  credit_card
# 4  0bb98ba72dcc08e95f9d8cc434e9a2cc  credit_card

# %%
#Análisis de pagos por estado
dfClientes.groupby(by='customer_state')[['payment_value']].agg(['sum','mean','median']).sort_values(by=('payment_value','sum'),ascending=False)
# Out:
#                payment_value
#                          sum          mean   median
# customer_state
# SP               755341148.0  15373.397676   9758.0
# RJ               274786023.0  18095.885611  11456.0
# MG               231063309.0  17077.849889  11276.0
# RS               113548531.0  17642.717682  11536.5
# PR               105890629.0  17923.261510  10980.5
# BA                78876911.0  19748.851027  11796.0
# SC                77960848.0  18326.480489  11699.5
# GO                50768290.0  21188.768781  11704.5
# DF                43273316.0  17540.865829  11435.0
# ES                40549265.0  17388.192539  11102.0
# PE                37196462.0  19806.422790  13304.0
# CE                33880608.0  22029.003901  13476.5
# MT                25590818.0  22930.840502  12916.0
# PA                25123769.0  22777.669084  14804.0
# MA                19695312.0  23502.758950  13812.0
# PB                17778166.0  28219.311111  15531.5
# MS                16537008.0  19524.212515  12353.0
# PI                13602199.0  23989.768959  15262.0
# RN                11562114.0  20463.918584  13824.0
# AL                11089667.0  24213.246725  13809.0
# SE                 8821447.0  22332.777215  14412.0
# TO                 7150556.0  21408.850299  13733.0
# RO                 6496706.0  23202.521429  15880.5
# AM                 3355912.0  19740.658824  12690.0
# AC                 2485752.0  26728.516129  18683.0
# AP                 2164270.0  25765.119048  16660.0
# RR                 1216039.0  24320.780000  16724.0

# %%
#Análisis de consumos por estado

dfClientes.sort_values(by='customer_state',ascending=False)
dfAcumuladosClientes = dfClientes.groupby(by='customer_state')[['customer_id']].agg(['count']).sort_values(by=('customer_id','count'),ascending=False)
dfAcumuladosClientes['Participacion Porcentual'] = dfAcumuladosClientes.apply(lambda x: (x/(x.sum()))*100)
dfAcumuladosClientes['Porcentaje acumulado'] = dfAcumuladosClientes['Participacion Porcentual'].cumsum()/dfAcumuladosClientes['Participacion Porcentual'].sum()*100
dfAcumuladosClientes.sort_values(by='Porcentaje acumulado',ascending=False)
dfAcumuladosClientes
# Out:
#                customer_id Participacion Porcentual Porcentaje acumulado
#                      count
# customer_state
# SP                   49133                42.144946            42.144946
# RJ                   15185                13.025279            55.170225
# MG                   13530                11.605665            66.775890
# RS                    6436                 5.520625            72.296515
# PR                    5908                 5.067721            77.364236
# SC                    4254                 3.648965            81.013201
# BA                    3994                 3.425944            84.439145
# DF                    2467                 2.116125            86.555271
# GO                    2396                 2.055223            88.610494
# ES                    2332                 2.000326            90.610820
# PE                    1878                 1.610897            92.221717
# CE                    1538                 1.319254            93.540972
# MT                    1116                 0.957274            94.498246
# PA                    1103                 0.946123            95.444369
# MS                     847                 0.726533            96.170903
# MA                     838                 0.718814            96.889716
# PB                     630                 0.540397            97.430113
# PI                     567                 0.486357            97.916470
# RN                     565                 0.484642            98.401112
# AL                     458                 0.392860            98.793972
# SE                     395                 0.338820            99.132792
# TO                     334                 0.286496            99.419288
# RO                     280                 0.240176            99.659464
# AM                     170                 0.145821            99.805286
# AC                      93                 0.079773            99.885058
# AP                      84                 0.072053            99.957111
# RR                      50                 0.042889           100.000000

# %%
#Diagrama de Pareto
fig, ax = plt.subplots(figsize=(10,10))
ax.bar(dfAcumuladosClientes.index, dfAcumuladosClientes[('customer_id','count')], color="C1")
ax2 = ax.twinx()
ax2.plot(dfAcumuladosClientes.index, dfAcumuladosClientes['Porcentaje acumulado'], color="C2", marker="o", ms=10)
ax2.yaxis.set_major_formatter(PercentFormatter())
ax.tick_params(axis="y", colors="C1")
ax2.tick_params(axis="y", colors="C1")
ax2.set_title('Diagrama de Pareto para Ordenes acumuladas por Estado')
plt.show()

# %%
#Participación de los principales estados de consumo
plt.figure(figsize=(6,6))
sns.set_style('darkgrid')
ax = dfClientes.customer_state.value_counts().sort_values(ascending=False)[0:10].plot(kind='pie')
ax.set_title("Top 30 estados consumidores")
ax.set_xlabel("Estados")
plt.xticks(rotation=35)
plt.show()

# %% [markdown]
# ### Conclusion 1

# %% [markdown]
# El 67% de las ganancias por ventas provienen de Sao Paulo, Rio de Janeiro y Minas Gerais con mayor concentración en Sao Paulo (Monto por Ventas). Esto permitiría a Olist concentrase en dichos estados por sobre el resto.
#
# Debería hacerse un análisis detallado de los productos consumidos en cada región para entender el patrón de consumo (la mediana de las ordenes indica que no está en esos 3 estados el valor mas alto por orden)

# %%
dfPagos = dfClientes.groupby(by='payment_type')[['customer_id']].agg(['count']).sort_values(by=('customer_id','count'),ascending=False)

dfPagos['Porcentaje de Consumidores'] = dfPagos.apply(lambda x: (x/(x.sum()))*100)

dfPagos['Payments'] = np.round(dfClientes.groupby(by='payment_type')[['payment_value']].agg(['sum']),4)

Monto_Total = dfPagos['Payments'].sum()
dfPagos
# Out:
#              customer_id Porcentaje de Consumidores      Payments
#                    count
# payment_type
# credit_card        86012                  73.778746  1.548198e+09
# boleto             22692                  19.464578  4.024296e+08
# voucher             6211                   5.327626  4.017006e+07
# debit_card          1666                   1.429049  2.500779e+07

# %% [markdown]
# ### Conclusion 2

# %% [markdown]
# 74% de las ventas se abonan con tarjeta de crédito
#
# 19% de las ventas se abonan con boleto
#
# El bajo porcentaje de utilización de vouchers señala una posibilidad de marketing y estrategia de fidelizacion de clientes

# %%
import pandas_profiling
from pandas_profiling import ProfileReport

report = ProfileReport(dfOrdenesCompletas)

print(repr(report.report))

report.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/52 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Root
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ## Analisis bivariado

# %%
#Análisis de los productos preferidos
dfProdPreferences = dfOrdenesCompletas.groupby(by='product_category_name_english')[['customer_id']].agg(['count']).sort_values(by=('customer_id','count'),ascending=False)
dfProdPreferences['Porcentaje de participación de Consumidores'] = dfProdPreferences.apply(lambda x: (x/(x.sum()))*100)
dfProdPreferences
# Out:
#                               customer_id  \
#                                     count
# product_category_name_english
# bed_bath_table                      11990
# health_beauty                       10030
# sports_leisure                       9005
# furniture_decor                      8833
# computers_accessories                8151
# ...                                   ...
# arts_and_craftmanship                  24
# la_cuisine                             16
# cds_dvds_musicals                      14
# fashion_childrens_clothes               8
# security_and_services                   2
#
#                               Porcentaje de participación de Consumidores
#
# product_category_name_english
# bed_bath_table                                                  10.284695
# health_beauty                                                    8.603460
# sports_leisure                                                   7.724243
# furniture_decor                                                  7.576706
# computers_accessories                                            6.991705
# ...                                                                   ...
# arts_and_craftmanship                                            0.020587
# la_cuisine                                                       0.013724
# cds_dvds_musicals                                                0.012009
# fashion_childrens_clothes                                        0.006862
# security_and_services                                            0.001716
#
# [71 rows x 2 columns]

# %%
dfPrincipalProductoConsumido = dfProdPreferences[0:10]
dfPrincipalProductoConsumido.sum()
# Out:
# customer_id                                  count    75318.000000
# Porcentaje de participación de Consumidores              64.605725
# dtype: float64

# %% [markdown]
# ### Conclusion 3

# %% [markdown]
# Las principales categorías de productos consumidos son: ambientes del hogar, belleza, deportes, decoracion y computación.
#
# Las 10 categorías mas consumidas se llevan el 64% del consumo

# %% [markdown]
# #Análisis de corelaciones

# %%
correlation = dfOrdenesCompletas.corr(method="pearson")
correlation.head()
# Out:
#                                price  freight_value  customer_zip_code_prefix  \
# price                       1.000000       0.416591                  0.042941
# freight_value               0.416591       1.000000                  0.225468
# customer_zip_code_prefix    0.042941       0.225468                  1.000000
# product_name_lenght         0.017963       0.022629                  0.015831
# product_description_lenght  0.201692       0.096484                  0.025364
#
#                             product_name_lenght  product_description_lenght  \
# price                                  0.017963                    0.201692
# freight_value                          0.022629                    0.096484
# customer_zip_code_prefix               0.015831                    0.025364
# product_name_lenght                    1.000000                    0.090245
# product_description_lenght             0.090245                    1.000000
#
#                             product_weight_g  product_length_cm  \
# price                               0.340539           0.145636
# freight_value                       0.612936           0.308372
# customer_zip_code_prefix            0.002730           0.005163
# product_name_lenght                 0.020718           0.058687
# product_description_lenght          0.063553           0.007471
#
#                             product_height_cm  product_width_cm  \
# price                                0.224322          0.172290
# freight_value                        0.394073          0.324111
# customer_zip_code_prefix             0.012011         -0.010367
# product_name_lenght                 -0.030914          0.062135
# product_description_lenght           0.074157         -0.068264
#
#                             payment_value  seller_zip_code_prefix
# price                            0.738048                0.088985
# freight_value                    0.373490                0.151844
# customer_zip_code_prefix         0.054158                0.076241
# product_name_lenght              0.002341               -0.032565
# product_description_lenght       0.156024                0.062242

# %%
plt.figure(figsize=(15,15)) #Defino el tamaño del grafico

#Genero el mapa de calor
sns.heatmap(correlation, 
            cbar = True, 
            square = True, 
            annot=True,
            fmt= '.2f',
            annot_kws={'size': 15},
            cmap= 'coolwarm') 

#Roto los ejes para que queden inclinados
plt.xticks(rotation = 45)
plt.yticks(rotation = 45)
plt.show()

# %% [markdown]
# ### Conclusion 4

# %% [markdown]
# Conviene estudiar mas en detalle la relacion entre:
#
# - order_item_id y payment_value (linea de pedido y valor del pago)
#
# - product_weight y freight_value (peso del producto y valor del flete)
#
# - price y payment_installments (precio y cuotas)

# %% [markdown]
# # TP 2 - Modelos y medidas -  Árbol de decisión

# %%
#Importo librerías

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
#Hago un head del df

dfOrdenesCompletas.head()
# Out:
#                            order_id                       customer_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1  130898c0987d1801452a8ed92a670612  e6eecc5a77de221464d1c4eaff0a9b64
# 2  532ed5e14e24ae1f0d735b91524b98b9  4ef55bf80f711b372afebcb7c715344a
# 3  6f8c31653edb8c83e1a739408b5ff750  30407a72ad8b3f4df4d15369126b20c9
# 4  7d19f4ef4d04461989632411b7e588b9  91a792fef70ecd8cc69d3c7feb3d12da
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-09-13 08:59:02 2017-09-13 09:45:35
# 1    delivered      2017-06-28 11:52:20 2017-06-29 02:44:11
# 2    delivered      2018-05-18 10:25:53 2018-05-18 12:31:43
# 3    delivered      2017-08-01 18:38:42 2017-08-01 18:55:08
# 4    delivered      2017-08-10 21:48:40 2017-08-10 22:05:11
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-09-19 18:34:16           2017-09-20 23:43:48
# 1          2017-07-05 12:00:33           2017-07-13 20:39:29
# 2          2018-05-23 14:05:00           2018-06-04 18:34:26
# 3          2017-08-02 19:07:36           2017-08-09 21:26:33
# 4          2017-08-11 19:43:07           2017-08-24 20:04:21
#
#   order_estimated_delivery_date order_item_id  \
# 0                    2017-09-29             1
# 1                    2017-07-26             1
# 2                    2018-06-07             1
# 3                    2017-08-25             1
# 4                    2017-09-01             1
#
#                          product_id  ... seller_zip_code_prefix  \
# 0  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 1  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 2  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 3  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
# 4  4244733e06e7ecb4970a6e2683c13e61  ...                  27277
#
#      seller_city  seller_state  product_category_name_english  \
# 0  volta redonda            SP                     cool_stuff
# 1  volta redonda            SP                     cool_stuff
# 2  volta redonda            SP                     cool_stuff
# 3  volta redonda            SP                     cool_stuff
# 4  volta redonda            SP                     cool_stuff
#
#                           review_id  review_score review_comment_title  \
# 0  97ca439bc427b48bc1cd7177abe71365             5           Sin Titulo
# 1  b11cba360bbe71410c291b764753d37f             5           Sin Titulo
# 2  af01c4017c5ab46df6cc810e069e654a             4      super recomendo
# 3  8304ff37d8b16b57086fa283fe0c44f8             5           Sin Titulo
# 4  426f43a82185969503fb3c86241a9535             5           Sin Titulo
#
#                               review_comment_message review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.           2017-09-21
# 1  lannister como sempre, entregou certinho e den...           2017-07-14
# 2                              carrinho muito bonito           2018-06-05
# 3                                       Sin Revision           2017-08-10
# 4                                       Sin Revision           2017-08-25
#
#    review_answer_timestamp
# 0      2017-09-22 10:57:03
# 1      2017-07-17 12:50:07
# 2      2018-06-06 21:41:12
# 3      2017-08-13 03:35:17
# 4      2017-08-28 00:51:18
#
# [5 rows x 40 columns]

# %%
#Vamos a intentar predecir el valor de la review partiendo de las variables "order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"
columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]
X = dfOrdenesCompletas[columns]
y = dfOrdenesCompletas.review_score #Defino el target

# %%
#Divido el dataset en train y test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=77)

# %%
#Creo el modelo

tree = DecisionTreeClassifier(max_depth=2, random_state = 77)

# %%
#Entreno el modelo

tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=77)

# %%
y_train_pred = tree.predict(X_train) #Prediccion en Train
y_test_pred = tree.predict(X_test) #Prediccion en Test

# %%
#Calculo el accuracy en Train
train_accuracy = accuracy_score(y_train, y_train_pred)

#Calculo el accuracy en Test
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de entrenamiento:', train_accuracy)
print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.5605592726025047
# % de aciertos sobre el set de evaluación: 0.5648606147248034

# %%
#Analizo cuáles variables son las más importantes dentro del modelo

plt.figure(figsize=(15,15))
importances = tree.feature_importances_
columns = X.columns
sns.barplot(columns, importances)
plt.title('Importancia de cada Feature')
plt.show()

# %% [markdown]
# ### Conclusión 5

# %% [markdown]
# Pese a la casi nula correlación que existía en las variables, luego de entrenar el modelo logramos que el mismo reproduzca con un 55% de acierto la calificación de la review del cliente. Es probable que este resultado se haya logrado gracias a la gran cantidad de observaciones con las que cuenta el dataset.
# También es importante destacar que parece que 3 variables serían inútiles en el modelo, bastaría con utilizar 'order_purchase_timestamp' y 'order_delivered_customer_date' para alcanzar resultados similares.
# Debido a la poca diferencia que se aprecia entre los porcentajes de aciertos entre el conjunto de 'train' y el de 'test' podríamos afirmar que nuestro modelo no sufre de overfitting.

# %% [markdown]
# # TP 3 - Modelos y medidas

# %% [markdown]
# ## NLP sobre comentarios y scores de ordenes

# %%
import nltk
import re
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from imblearn.over_sampling import RandomOverSampler

# %%
nltk.download('stopwords')
stop_words = stopwords.words('portuguese')
nltk.download('punkt')
lemmatizer=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KRosa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KRosa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
dfOrderS=pd.read_sql("SELECT * from olist_order_reviews", conn)

# %%
n_of_records = dfOrderS['review_comment_message'].isnull().sum()
print(f'Nro def filas sin comentarios : {n_of_records}')
print(f'Nro def filas con comentarios {len(dfOrderS)-n_of_records}')
# Out:
# Nro def filas sin comentarios : 58254
# Nro def filas con comentarios 41746

# %%
dfOrderS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  object
#  3   review_comment_title     11713 non-null   object
#  4   review_comment_message   41746 non-null   object
#  5   review_creation_date     100000 non-null  datetime64[ns]
#  6   review_answer_timestamp  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 5.3+ MB

# %%
# Transformo review_score en un float
dfOrderS['review_score']=dfOrderReviews['review_score'].astype('float64')

# %%
dfOrderS.describe()
# Out:
#         review_score
# count  100000.000000
# mean        4.070890
# std         1.359663
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %% [markdown]
# ## Distribución de reviews
# Buscamos responder:
#
# ¿Los datos son muy escasos?
#
# ¿Están concentrados los datos?
#
# Podemos ver que los datos se concentran en torno a la revisión de 5 estrellas y la revisión de 1 estrella.
#
# Vamos a equilibrar estos datos

# %%
sns.barplot(x = np.unique(y), y = [list(y).count(i) for i in np.unique(y)])
# Out:
# <AxesSubplot:>

# %%
for i in np.unique(y):
    print(f'El porcentaje de Score {i} en los datos es {list(y).count(i)/len(dfOrderReviews)*100} %')
# Out:
# El porcentaje de Score 1.0 en los datos es 11.858 %
# El porcentaje de Score 2.0 en los datos es 3.235 %
# El porcentaje de Score 3.0 en los datos es 8.286999999999999 %
# El porcentaje de Score 4.0 en los datos es 19.2 %
# El porcentaje de Score 5.0 en los datos es 57.42 %

# %% [markdown]
# ## Pre Procesamiento de datos de texto
# Tomamos el texto y eliminamos cualquier tipo de caracteres especiales.
#
# Eliminamos palabras vacías en portugués del texto

# %%
dfOrderS.head()
# Out:
#                           review_id                          order_id  \
# 0  0001239bc1de2e33cb583967c2ca4c67  fc046d7776171871436844218f817d7d
# 1  0001cc6860aeaf5b9017fe4131a52e62  d4665434b01caa9dc3e3e78b3eb3593e
# 2  00020c7512a52e92212f12d3e37513c0  e28abf2eb2f1fbcbdc2dd0cd9a561671
# 3  00032b0141443497c898b3093690af51  04fb47576993a3cb0c12d4b25eab6e4e
# 4  00034d88989f9a4c393bdcaec301537f  5f358d797a49fe2f24352f73426215f6
#
#    review_score review_comment_title  \
# 0           5.0                 None
# 1           5.0                 None
# 2           5.0      Entrega rápida!
# 3           5.0                 None
# 4           5.0                 None
#
#                               review_comment_message review_creation_date  \
# 0                                               None           2018-03-20
# 1                                               None           2018-06-22
# 2  a entrega foi super rápida e o pendente é lind...           2018-04-25
# 3                                               None           2017-05-30
# 4                                               None           2017-08-12
#
#   review_answer_timestamp
# 0     2018-03-20 18:36:04
# 1     2018-06-26 13:51:29
# 2     2018-04-26 14:55:36
# 3     2017-06-01 23:28:55
# 4     2017-08-13 19:56:53

# %%
dfOrderS.describe()
# Out:
#         review_score
# count  100000.000000
# mean        4.070890
# std         1.359663
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
# Limpieza de datos
# Remoción de comentarios vacíos
# Análisis depérdida de datos
nFilas = dfOrderS['review_comment_message'].isnull().sum()
print(f'Número de filas sin comentarios : {nFilas}')
print(f'Número de filas con comentarios: {len(dfOrderS)-nFilas}')

Campos_Nulos= [feature for feature in dfOrderS.columns if dfOrderS[feature].isnull().sum()>=1]
for feature in Campos_Nulos:
    print('Feature ', feature, np.round(dfOrderS[feature].isnull().mean()*100,4),'%', ' y el total de nulos es ', np.round(dfOrderS[feature].isnull().sum(),4))
# Out:
# Número de filas sin comentarios : 58254
# Número de filas con comentarios: 41746
# Feature  review_comment_title 88.287 %  y el total de nulos es  88287
# Feature  review_comment_message 58.254 %  y el total de nulos es  58254

# %%
dfOrderS=dfOrderS.dropna()

# %%
nFilas = dfOrderS['review_comment_message'].isnull().sum()
print(f'Número de filas sin comentarios : {nFilas}')
print(f'Número de filas con comentarios: {len(dfOrderS)-nFilas}')

Campos_Nulos= [feature for feature in dfOrderS.columns if dfOrderS[feature].isnull().sum()>=1]
for feature in Campos_Nulos:
    print('Feature ', feature, np.round(dfOrderS[feature].isnull().mean()*100,4),'%', ' y el total de nulos es ', np.round(dfOrderS[feature].isnull().sum(),4))
# Out:
# Número de filas sin comentarios : 0
# Número de filas con comentarios: 9984

# %%
y = dfOrderS.pop('review_score')

# %%
dfOrderS
# Out:
#                               review_id                          order_id  \
# 2      00020c7512a52e92212f12d3e37513c0  e28abf2eb2f1fbcbdc2dd0cd9a561671
# 7      00046a69550325aea5fb89f65c7387f2  9fbda7367628952bc36c3512c46d887b
# 13     000688fa7009b3c9fafe4950b37cbc81  f7445b0cae0fd4d05894171adcc55931
# 28     00112b1cb3cd58339c91aad88df2b835  c7068b2d09a51ca53dd0a06c2526be34
# 35     00148610066c357531807daea5888a22  8f705decc6b7168523d676183f61b950
# ...                                 ...                               ...
# 99942  ffd23fd8bdd92b248c78db6dd5809104  6d4e74b6495388cdfde5999070ad25d7
# 99947  ffda963529fcb525067c642cf666b175  5fb90fed46dfc44305e1c3ecb5f16a2d
# 99955  ffdedfdb2405f13967c76175160acd3e  b378d3979dc4d1d8bd701f93e8b7ce6a
# 99966  ffe556cda2b136b51ede6d5ce5559a53  b23fef1fa296cd791a57b465a3dc3827
# 99974  ffec6410b1f1d834f07afcc4800f2f2e  45c653bdeb327fde86e2a52bd3d33e89
#
#           review_comment_title  \
# 2              Entrega rápida!
# 7              SUPER RECOMENDO
# 13                         Bom
# 28        Entrega muito rápida
# 35     ENTREGA DENTRO DO PRAZO
# ...                        ...
# 99942                Recomendo
# 99947         Super recomendo.
# 99955                Recomendo
# 99966          Super recomendo
# 99974               Recomendo.
#
#                                   review_comment_message review_creation_date  \
# 2      a entrega foi super rápida e o pendente é lind...           2018-04-25
# 7      gostei da capinha de celular, veio como eu esp...           2018-07-01
# 13                                   meu sait preferido            2018-06-19
# 28     nota 10 pela entrega.\r\no produto não tem a c...           2018-05-03
# 35                   entrega dentro do prazo..recomendo!           2018-05-16
# ...                                                  ...                  ...
# 99942                     ainda experimentando o produto           2018-08-02
# 99947                             excelente atendimento.           2018-05-05
# 99955       o produto chegou certo e bem antes do prazo.           2018-06-30
# 99966  produto chegou antes do prazo e com ótima qual...           2018-06-15
# 99974                        muito boa a loja. parabéns.           2018-06-12
#
#       review_answer_timestamp
# 2         2018-04-26 14:55:36
# 7         2018-07-02 12:32:24
# 13        2018-06-20 04:48:13
# 28        2018-05-03 22:14:11
# 35        2018-05-25 17:57:16
# ...                       ...
# 99942     2018-08-03 12:43:45
# 99947     2018-05-08 16:04:54
# 99955     2018-07-04 00:35:42
# 99966     2018-06-15 19:18:50
# 99974     2018-06-14 01:14:24
#
# [9984 rows x 6 columns]

# %%
texts = dfOrderS['review_comment_message']

# %%
texts
# Out:
# 2        a entrega foi super rápida e o pendente é lind...
# 7        gostei da capinha de celular, veio como eu esp...
# 13                                     meu sait preferido
# 28       nota 10 pela entrega.\r\no produto não tem a c...
# 35                     entrega dentro do prazo..recomendo!
#                                ...
# 99942                       ainda experimentando o produto
# 99947                               excelente atendimento.
# 99955         o produto chegou certo e bem antes do prazo.
# 99966    produto chegou antes do prazo e com ótima qual...
# 99974                          muito boa a loja. parabéns.
# Name: review_comment_message, Length: 9984, dtype: object

# %%
nltk.download('stopwords')
stop_words = stopwords.words('portuguese')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KRosa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words=nltk.corpus.stopwords.words('portuguese')
wordcloud = WordCloud(stopwords=stop_words,
                      background_color="black",
                      width=1600, height=800).generate(str(texts))

plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()
plt.savefig("WordCloud.png")

# %%
def pre_process_data(text):
    lemm = WordNetLemmatizer()
    text  = re.sub(r"[^0-9a-zA-Z]+",' ',text)
    tokenized = word_tokenize(text)
    text = [lemm.lemmatize(i.lower()) for i in tokenized if not(i.lower() in stop_words) and i.isalpha()]
    return ' '.join(text)

# %%
n_samples = 10000
n_features = 100000
n_components = 10
n_top_words = 20

# %%
dfOrderS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9984 entries, 2 to 99974
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                9984 non-null   object
#  1   order_id                 9984 non-null   object
#  2   review_comment_title     9984 non-null   object
#  3   review_comment_message   9984 non-null   object
#  4   review_creation_date     9984 non-null   datetime64[ns]
#  5   review_answer_timestamp  9984 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(4)
# memory usage: 546.0+ KB

# %%
texts
# Out:
# 2        a entrega foi super rápida e o pendente é lind...
# 7        gostei da capinha de celular, veio como eu esp...
# 13                                     meu sait preferido
# 28       nota 10 pela entrega.\r\no produto não tem a c...
# 35                     entrega dentro do prazo..recomendo!
#                                ...
# 99942                       ainda experimentando o produto
# 99947                               excelente atendimento.
# 99955         o produto chegou certo e bem antes do prazo.
# 99966    produto chegou antes do prazo e com ótima qual...
# 99974                          muito boa a loja. parabéns.
# Name: review_comment_message, Length: 9984, dtype: object

# %%
vectorizer = CountVectorizer(max_features=10000)
vectorizer2 = TfidfTransformer()
x = vectorizer.fit_transform(texts)
x = vectorizer2.fit_transform(x,y)

# %%
texts = [pre_process_data(i) for i in texts]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)
rf_model = RandomForestClassifier(n_jobs=5,verbose=1)

# %%
scores_nos = cross_val_score(rf_model,x,y)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    6.9s finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  70 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  70 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  70 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  70 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    4.1s finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
print(f'Promedio de scoring para set de datos sin oversampling {scores_nos.mean()}')
# Out:
# Promedio de scoring para set de datos sin oversampling 0.6802886694771616

# %%
rf_model.fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    3.4s finished
# RandomForestClassifier(n_jobs=5, verbose=1)

# %%
y_pred = rf_model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.60      0.85      0.70       484
#          2.0       0.43      0.03      0.05       111
#          3.0       0.33      0.03      0.06       181
#          4.0       0.28      0.04      0.07       340
#          5.0       0.75      0.94      0.84      1380
#
#     accuracy                           0.70      2496
#    macro avg       0.48      0.38      0.34      2496
# weighted avg       0.61      0.70      0.62      2496
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=5)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [raw]
# plot_confusion_matrix(rf_model,x_test,y_test)

# %% [markdown]
# ## Analisis con set completo - Incluye review_comments=NaN

# %% [markdown]
# Vamor a recuperar el data set completo, pero en lugar de eliminar los conjuntos NaN, vamos a completarlos con la frase "Sin Datos" ya que muchos registros no tienen feedback pero si tienen scoring.
#
# ### Oversampling

# %%
ro = RandomOverSampler()
x_ros, y_ros = ro.fit_resample(x, y)
x_train,x_test,y_train,y_test = train_test_split(x_ros,y_ros)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-595-4027c0b19b06> in <module>
#       1 ro = RandomOverSampler()
# ----> 2 x_ros, y_ros = ro.fit_resample(x, y)
#       3 x_train,x_test,y_train,y_test = train_test_split(x_ros,y_ros)
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# C:\ProgramData\Anaconda3\lib\site-packages\imblearn\over_sampling\_random_over_sampler.py in _check_X_y(self, X, y)
#     138     def _check_X_y(self, X, y):
#     139         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 140         X, y = self._validate_data(
#     141             X,
#     142             y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     829         y = y.astype(np.float64)
#     830
# --> 831     check_consistent_length(X, y)
#     832
#     833     return X, y
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 100000]

# %%
## Borrar
from bs4 import BeautifulSoup

# %%
dfOrderS2=pd.read_sql("SELECT * from Order_review_V", conn)

n_of_records = dfOrderS2['review_score'].isnull().sum()
print(f'Nro def filas sin score : {n_of_records}')
print(f'Nro def filas con score {len(dfOrderS2)-n_of_records}')

dfOrderS2.info()
# Out:
# Nro def filas sin score : 0
# Nro def filas con score 100000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  object
#  3   review_comment_title     11713 non-null   object
#  4   review_comment_message   41746 non-null   object
#  5   review_creation_date     100000 non-null  datetime64[ns]
#  6   review_answer_timestamp  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 5.3+ MB

# %%
dfOrderS2=dfOrderS2.fillna('Sin Review')

# %%
dfOrderS2['tokenized'] = dfOrderS2['review_score'].apply(word_tokenize)
dfOrderS2.head()
# Out:
#                           review_id                          order_id  \
# 0  0001239bc1de2e33cb583967c2ca4c67  fc046d7776171871436844218f817d7d
# 1  0001cc6860aeaf5b9017fe4131a52e62  d4665434b01caa9dc3e3e78b3eb3593e
# 2  00020c7512a52e92212f12d3e37513c0  e28abf2eb2f1fbcbdc2dd0cd9a561671
# 3  00032b0141443497c898b3093690af51  04fb47576993a3cb0c12d4b25eab6e4e
# 4  00034d88989f9a4c393bdcaec301537f  5f358d797a49fe2f24352f73426215f6
#
#   review_score review_comment_title  \
# 0            5           Sin Review
# 1            5           Sin Review
# 2            5      Entrega rápida!
# 3            5           Sin Review
# 4            5           Sin Review
#
#                               review_comment_message review_creation_date  \
# 0                                         Sin Review           2018-03-20
# 1                                         Sin Review           2018-06-22
# 2  a entrega foi super rápida e o pendente é lind...           2018-04-25
# 3                                         Sin Review           2017-05-30
# 4                                         Sin Review           2017-08-12
#
#   review_answer_timestamp tokenized
# 0     2018-03-20 18:36:04       [5]
# 1     2018-06-26 13:51:29       [5]
# 2     2018-04-26 14:55:36       [5]
# 3     2017-06-01 23:28:55       [5]
# 4     2017-08-13 19:56:53       [5]

# %%
nFilas = dfOrderS2['review_score'].isnull().sum()
print(f'Número de filas sin score : {nFilas}')
print(f'Número de filas con score: {len(dfOrderS2)-nFilas}')

Campos_Nulos= [feature for feature in dfOrderS2.columns if dfOrderS2[feature].isnull().sum()>=1]
for feature in Campos_Nulos:
    print('Feature ', feature, np.round(dfOrderS2[feature].isnull().mean()*100,4),'%', ' y el total de nulos es ', np.round(dfOrderS2[feature].isnull().sum(),4))
# Out:
# Número de filas sin score : 0
# Número de filas con score: 100000

# %%
scores = pd.DataFrame(dfOrderS2['tokenized'])

# %%
scores
# Out:
#       tokenized
# 0           [5]
# 1           [5]
# 2           [5]
# 3           [5]
# 4           [5]
# ...         ...
# 99995       [4]
# 99996       [5]
# 99997       [1]
# 99998       [5]
# 99999       [5]
#
# [100000 rows x 1 columns]

# %%
def pre_process_data_scores2(text):
    lemm = WordNetLemmatizer()
    return ' '.join(text)

# %%
vectorizer = CountVectorizer(max_features=10000)
vectorizer2 = TfidfTransformer()
x = vectorizer.fit_transform(scores)
x = vectorizer2.fit_transform(x,y)

# %%
scores = [pre_process_data_scores2(i) for i in dfOrderS2.tokenized]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)
rf_model = RandomForestClassifier(n_jobs=5,verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-594-5000c54b3b23> in <module>
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(x,y)
#       2 rf_model = RandomForestClassifier(n_jobs=5,verbose=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     297     """
#     298     result = [_make_indexable(X) for X in iterables]
# --> 299     check_consistent_length(*result)
#     300     return result
#     301
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 100000]

# %%
scores = [pre_process_data(i) for i in scores]

# %%
scores
# Out:
# ['n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  'n nname review score length dtype',
#  ...]

# %%
scores = dfOr['review_score']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'review_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-493-af5eaaae8780> in <module>
# ----> 1 scores = dfOrderS2['review_score']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'review_score'

# %%
scores.head()
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: review_score, dtype: float64

# %%
vectorizer = CountVectorizer(max_features=10000)
vectorizer2 = TfidfTransformer()
x = vectorizer.fit_transform(str(scores))
x = vectorizer2.fit_transform(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-480-5b0f9e919880> in <module>
#       1 vectorizer = CountVectorizer(max_features=10000)
#       2 vectorizer2 = TfidfTransformer()
# ----> 3 x = vectorizer.fit_transform(str(scores))
#       4 x = vectorizer2.fit_transform(x,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1191         # TfidfVectorizer.
#    1192         if isinstance(raw_documents, str):
# -> 1193             raise ValueError(
#    1194                 "Iterable over raw text documents expected, "
#    1195                 "string object received.")
#
# ValueError: Iterable over raw text documents expected, string object received.

# %%
texts = [pre_process_data(i) for i in texts]

x_train,x_test,y_train,y_test = train_test_split(x,y)
rf_model = RandomForestClassifier(n_jobs=5,verbose=1)

scores_nos = cross_val_score(rf_model,x,y)

print(f'The Average score for not oversampled data is {scores_nos.mean()}')

rf_model.fit(x_train,y_train)

y_pred = rf_model.predict(x_test)
print(classification_report(y_test,y_pred))

plot_confusion_matrix(rf_model,x_test,y_test)

## Analisis sobre los scores 4 y 5
